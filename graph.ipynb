# %% [markdown]
# <a href="https://colab.research.google.com/github/Franklin-Graham/machine/blob/master/graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0.0,0.24,0.29,0.34,0.33])
y = np.array([1.0,1.0,1.09,0.65,0.0])
x1 = np.array([0.0, 0.3, 0.36, 0.35,0.45,1.0])
y1 = np.array([1.0, 1.0, 1.05, 0.0,0.04,0.0])
x2 = np.array([0.0, 0.2, 0.35,0.4, 0.4])
y2 = np.array([1.0, 1.0, 1.09, 0.65, 0.0])
x3 = np.array([0.0, 0.2, 0.39, 0.38])
y3 = np.array([1.0, 1.0, 1.02, 0.0])
x4 = np.array([0.0, 0.3, 0.41, 0.48, 0.48])
y4 = np.array([1.0, 1.0, 1.08, 0.68, 0.0])
x5 = np.array([0.0, 0.4, 0.45,0.53, 0.53])
y5 = np.array([1.0, 1.0, 1.04,0.75, 0.0])
x6 = np.array([0.0, 0.05, 0.2,0.43,0.52,0.56,0.57,0.6,0.69])
y6 = np.array([1.0, 1.02, 1.0,1.0,1.06,0.8,0.0,0.09,0.0])

plt.xlim(0,1)
plt.ylim(0,1.2)  
plt.plot(x,y,color='violet')
plt.plot(x1,y1,color='black')
plt.plot(x2,y2,color='yellow')
plt.plot(x3,y3,color='cyan')
plt.plot(x4,y4,color='green')
plt.plot(x5,y5,color='red')
plt.plot(x6,y6,color='blue')
plt.ylabel('Magnitude Response', fontsize = 15)
plt.xlabel('Normalized Frequency', fontsize = 15)
plt.title('Magnitude response of 20th order FIR LPF', fontweight ='bold', fontsize = 13)

plt.show()

# %%
x1 = np.array([0.2,0.25,0.34,0.41,0.5,1.0])
y1 = np.array([0.0,0.05,0.0,1.11,1.0,1.0])
x2 = np.array([0.39, 0.48, 0.6, 1.0])
y2 = np.array([0.0, 1.09, 1.0, 1.0])
x3 = np.array([0.41, 0.43, 0.5, 0.6, 0.7, 1.0])
y3 = np.array([0.0, 0.2, 0.8, 1.0999, 1.0, 1.0])
x4 = np.array([0.41, 0.49, 0.53, 0.55, 0.69])
y4 = np.array([0.0, 0.4, 0.6, 0.8, 1.0999])
x5 = np.array([0.43, 0.58, 0.69, 0.74, 0.8, 0.89, 1.0])
y5 = np.array([0.0, 0.83, 1.0999, 0.88, 1.0999, 0.88, 1.0999])
x6 = np.array([0.51, 0.6, 0.66, 0.69])
y6 = np.array([0.0, 0.6, 0.78, 1.0999])
x7 = np.array([0.38, 0.42, 0.47, 0.62, 0.7, 0.78, 0.84, 0.88, 1.0])
y7 = np.array([0.0, 0.01, 0.0, 0.85, 1.1, 0.9, 1.1, 0.84, 1.0999])
plt.xlim(0,1)
plt.ylim(0,1.2)
plt.plot(x1,y1,color='blue')
plt.plot(x2,y2,color='black')
plt.plot(x3,y3,color='yellow')
plt.plot(x4,y4,color='violet')
plt.plot(x5,y5,color='red')
plt.plot(x6,y6,color='cyan')
plt.plot(x7,y7,color='green')
plt.ylabel('Magnitude Response', fontsize = 15)
plt.xlabel('Normalized Frequency', fontsize = 15)
plt.title('Magnitude response of 20th order FIR LPF', fontweight ='bold', fontsize = 13)
plt.show()
